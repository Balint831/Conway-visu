# %%
import pandas as pd
import matplotlib.pyplot as plt

mp = pd.read_csv("times_mp.txt",header = None)
mp = mp.T

st = pd.read_csv("times.txt", header = None)
st = st.T

gpu = pd.read_csv("gpu_runtimes.txt", header=None)
gpu = gpu.T # it is in milliseconds

# %%
st.columns = st.iloc[0]
st.drop(index = [0,11], inplace = True)

# %%
gpu.columns = gpu.iloc[0]
gpu.drop(index = [0,11], inplace = True)

# %%
mp.columns = mp.iloc[0]
mp.drop(index = [0,11], inplace = True)

# %%
plt.figure(figsize=[8,6])
plt.plot(st.min(axis=0), color="tab:red", label="single thread")
plt.plot(mp.min(axis=0), color ="tab:orange", label="multi thread")

plt.plot(gpu.min(axis=0)*1000, color="tab:purple", label="GPU")
plt.yscale("log")
plt.xscale("log")
plt.title("CPU multithreading", size =16)
plt.ylabel(r"min runtime [$\mu s$]", size=16)
plt.xlabel(r"$\sqrt{grid size}$", size=16)
plt.grid()
plt.legend()

# %%
plt.figure(figsize=[8,6])
plt.plot(st.min(axis=0))
plt.yscale("log")
plt.xscale("log")
plt.title("CPU single thread", size =16)
plt.ylabel(r"runtime min [$\mu s$]", size=16)
plt.xlabel(r"$\sqrt{grid size}$", size=16)
plt.grid()

# %%
st
# Out:
# 0   30.0     50.0     100.0    150.0    200.0    300.0    400.0    500.0    \
# 1     335.1    842.8   3406.4   8709.7  14973.4  29178.7  52626.2  79545.3
# 2     360.8    815.8   3522.9   7065.6  16692.8  35138.5  49880.7  77409.2
# 3     310.6    782.3   4032.7   8151.7  15848.3  37316.8  53422.2  79151.9
# 4     397.7    773.3   4373.5   6983.5  16075.4  35850.0  50251.8  81148.7
# 5     357.4    778.8   4246.3   7039.6  18244.6  31969.2  48632.8  80400.9
# 6     305.5    779.0   3477.8   7299.1  16600.0  44055.7  48520.3  80442.5
# 7     325.4   1571.5   4206.2   7262.0  17126.0  32764.9  48615.6  79784.9
# 8     330.7   3103.8   3840.2   7142.5  13558.4  31911.0  52360.9  81222.0
# 9     289.2    850.0   4973.8   7600.7  15603.9  32911.0  48541.0  78561.4
# 10    449.8    816.5   3297.5   9592.8  15710.5  28156.8  48749.4  75846.4
#
# 0    600.0     700.0     800.0     1000.0    1500.0     2000.0     2500.0   \
# 1   124062.0  156800.0  202010.0  321108.0  717780.0  1276320.0  2010320.0
# 2   113382.0  152444.0  204630.0  308639.0  693207.0  1232390.0  1946120.0
# 3   115322.0  156094.0  209648.0  325513.0  705622.0  1220210.0  1905430.0
# 4   113541.0  157809.0  198612.0  313977.0  692075.0  1221750.0  1931430.0
# 5   113434.0  158022.0  195216.0  309731.0  690723.0  1230780.0  1931540.0
# 6   110828.0  168587.0  194251.0  313963.0  693454.0  1283430.0  1906160.0
# 7   113164.0  175150.0  195682.0  311548.0  693252.0  1315730.0  1901290.0
# 8   116094.0  177850.0  199567.0  309383.0  685326.0  1264270.0  1921700.0
# 9   121025.0  163426.0  196790.0  307319.0  698619.0  1223580.0  1912580.0
# 10  110354.0  151344.0  197495.0  318293.0  684602.0  1249780.0  1917490.0
#
# 0     3000.0     5000.0      10000.0      15000.0      20000.0
# 1   2889800.0  7968170.0  31411600.0   70229000.0  124910000.0
# 2   2801190.0  7721250.0  30231500.0   67615200.0  120571000.0
# 3   2764830.0  7663720.0  30242300.0   67408100.0  125528000.0
# 4   2757990.0  7648370.0  30158900.0   67495800.0  124088000.0
# 5   2755390.0  7682770.0  30162900.0   67317600.0  122533000.0
# 6   2753910.0  7637630.0  30114700.0   67411100.0  122135000.0
# 7   2755560.0  7641360.0  29941900.0   67420400.0  121547000.0
# 8   2755060.0  7655160.0  29930200.0   67377100.0  123545000.0
# 9   2849990.0  7666040.0  29870800.0   67413200.0  125055000.0
# 10  2758960.0  7668170.0  29907300.0  910030000.0  122304000.0
